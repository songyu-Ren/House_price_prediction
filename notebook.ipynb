# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F

# %%
train_data = pd.read_csv('./train.csv')
train_data.shape
# Out:
# (1460, 81)

# %%
column_names_train = list(train_data.columns.values)
column_names_train
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
test_data = pd.read_csv('./test.csv')

# %%
column_names_test = list(test_data.columns.values)
column_names_test
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
test_data.shape
# Out:
# (1459, 80)

# %%
temp3 = []
for element in column_names_train:
    if element not in column_names_test:
        temp3.append(element)
 
print(temp3)
# Out:
# ['SalePrice']

# %%
train_data.iloc[0:4, [0, 1, 2, 3, -3, -2, -1]]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0   1          60       RL         65.0       WD        Normal     208500
# 1   2          20       RL         80.0       WD        Normal     181500
# 2   3          60       RL         68.0       WD        Normal     223500
# 3   4          70       RL         60.0       WD       Abnorml     140000

# %%
test_data.iloc[0:4, [0, 1, 2, 3, -3, -2, -1]]
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  YrSold SaleType SaleCondition
# 0  1461          20       RH         80.0    2010       WD        Normal
# 1  1462          20       RL         81.0    2010       WD        Normal
# 2  1463          60       RL         74.0    2010       WD        Normal
# 3  1464          60       RL         78.0    2010       WD        Normal

# %%
all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))
all_features.shape
# Out:
# (2919, 79)

# %%
all_features.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 79, dtype: object

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
numeric_features
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
all_features[numeric_features]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
all_features[numeric_features] = all_features[numeric_features].apply(lambda x:(x - x.mean())/(x.std()))
all_features[numeric_features]
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       0.067320    -0.184443 -0.217841     0.646073    -0.507197   1.046078
# 1      -0.873466     0.458096 -0.072032    -0.063174     2.187904   0.154737
# 2       0.067320    -0.055935  0.137173     0.646073    -0.507197   0.980053
# 3       0.302516    -0.398622 -0.078371     0.646073    -0.507197  -1.859033
# 4       0.067320     0.629439  0.518814     1.355319    -0.507197   0.947040
# ...          ...          ...       ...          ...          ...        ...
# 1454    2.419286    -2.069222 -1.043758    -1.481667     1.289537  -0.043338
# 1455    2.419286    -2.069222 -1.049083    -1.481667    -0.507197  -0.043338
# 1456   -0.873466     3.884968  1.246594    -0.772420     1.289537  -0.373465
# 1457    0.655311    -0.312950  0.034599    -0.772420    -0.507197   0.682939
# 1458    0.067320     0.201080 -0.068608     0.646073    -0.507197   0.715952
#
# ...

# %%
all_features[numeric_features] = all_features[numeric_features].fillna(0)
all_features[numeric_features]
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       0.067320    -0.184443 -0.217841     0.646073    -0.507197   1.046078
# 1      -0.873466     0.458096 -0.072032    -0.063174     2.187904   0.154737
# 2       0.067320    -0.055935  0.137173     0.646073    -0.507197   0.980053
# 3       0.302516    -0.398622 -0.078371     0.646073    -0.507197  -1.859033
# 4       0.067320     0.629439  0.518814     1.355319    -0.507197   0.947040
# ...          ...          ...       ...          ...          ...        ...
# 1454    2.419286    -2.069222 -1.043758    -1.481667     1.289537  -0.043338
# 1455    2.419286    -2.069222 -1.049083    -1.481667    -0.507197  -0.043338
# 1456   -0.873466     3.884968  1.246594    -0.772420     1.289537  -0.373465
# 1457    0.655311    -0.312950  0.034599    -0.772420    -0.507197   0.682939
# 1458    0.067320     0.201080 -0.068608     0.646073    -0.507197   0.715952
#
# ...

# %%
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (2919, 331)

# %%
n_train = train_data.shape[0]
n_train
# Out:
# 1460

# %%
train_features = np.array(all_features[:n_train].values)
train_features
# Out:
# array([[ 0.06731988, -0.18444262, -0.21784137, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.87346638,  0.45809588, -0.07203174, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.06731988, -0.05593492,  0.13717338, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.30251644, -0.14160672, -0.14278111, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.87346638, -0.05593492, -0.0571972 , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.87346638,  0.24391638, -0.02930318, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
test_features = np.array(all_features[n_train:].values)
train_labels = np.array(train_data.SalePrice.values).reshape((-1, 1))

# %%
# Convert the NumPy arrays to PyTorch tensors
train_features_tensor = torch.tensor(train_features).float()
test_features_tensor = torch.tensor(test_features).float()
train_labels_tensor = torch.tensor(train_labels).float()

# %%
num_features = train_features_tensor.shape[1]
num_features
# Out:
# 331

# %%
num_features = train_features_tensor.shape[1]

# Define the L2 Loss (Mean Squared Error Loss)
loss = nn.MSELoss()

# Define the model
model = nn.Sequential(
    nn.Linear(num_features, 64),
    nn.ReLU(),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 1)
)
# Initialize the model's weights
for layer in model.modules():
    if isinstance(layer, nn.Linear):
        nn.init.xavier_uniform_(layer.weight)

# %%
# Define the log_rmse function
def log_rmse(model, features, labels):
    with torch.no_grad():
        clipped_preds = torch.clamp(model(features), 1, float('inf'))
        rmse = torch.sqrt(2 * loss(clipped_preds.log(), labels.log()).mean())
    return rmse.item()

# %%
# Define the training function
def train(model, train_features, train_labels, test_features, num_epochs, learning_rate, weight_decay, batch_size):
    train_ls = []
    
    train_dataset = TensorDataset(train_features_tensor, train_labels_tensor)
    train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True)
    
    # Using the Adam optimizer from PyTorch
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    
    for epoch in range(num_epochs):
        for X, y in train_dataloader:
            # Set model to training mode
            model.train()
            
            # Forward pass
            outputs = model(X)
            l = loss(outputs, y)
            
            # Backward pass and optimization
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            
        train_ls.append(log_rmse(model, train_features_tensor, train_labels_tensor))
        
    
    return train_ls

# %%
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train = torch.empty((0, X.shape[1]))  # Assuming X has 2 dimensions
    y_train = torch.empty((0,))
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]
        if j == i:
            X_valid = X_part
        else:
            X_train = torch.cat((X_train, X_part), dim=0)
            y_train = torch.cat((y_train, y_part), dim=0)
        
    return X_train, y_train, X_valid


def k_fold(k, X_train, y_train, num_epochs, learning_rate, weight_decay, batch_size):
    train_l_sum = 0.0
    for i in range(k):
        data = get_k_fold_data(k, i, X_train, y_train)
        train_ls, valid_ls = train(model, train_features, train_labels, test_features, num_epochs, learning_rate, weight_decay, batch_size)
        train_l_sum += train_ls[-1]
        print("fold %d, train rmse: %.4f" % (i, train_ls[-1]))
    return train_l_sum / k

k, num_epochs, lr, weight_decay, batch_size = 100, 100, 2, 0, 64

train_l = k_fold(k, train_features_tensor, train_labels_tensor, num_epochs, lr, weight_decay, batch_size)
print("%d-fold validation: avg train rmse: %f" % (k, train_l))
# Out:
# fold 0, train rmse: 0.5666
# fold 1, train rmse: 0.5688
# fold 2, train rmse: 0.5709
# fold 3, train rmse: 0.5727
# fold 4, train rmse: 0.5740
# fold 5, train rmse: 0.5749
# fold 6, train rmse: 0.5755
# fold 7, train rmse: 0.5758
# fold 8, train rmse: 0.5761
# fold 9, train rmse: 0.5762
# fold 10, train rmse: 0.5763
# fold 11, train rmse: 0.5763
# fold 12, train rmse: 0.5764
# fold 13, train rmse: 0.5764
# fold 14, train rmse: 0.5764
# fold 15, train rmse: 0.5764
# fold 16, train rmse: 0.5764
# fold 17, train rmse: 0.5764
# fold 18, train rmse: 0.5764
# fold 19, train rmse: 0.5764
# fold 20, train rmse: 0.5764
# fold 21, train rmse: 0.5764
# fold 22, train rmse: 0.5764
# fold 23, train rmse: 0.5764
# fold 24, train rmse: 0.5764
# fold 25, train rmse: 0.5764
# fold 26, train rmse: 0.5765
# fold 27, train rmse: 0.5764
# fold 28, train rmse: 0.5764
# fold 29, train rmse: 0.5764
# fold 30, train rmse: 0.5764
# fold 31, train rmse: 0.5764
# fold 32, train rmse: 0.5764
# ...
